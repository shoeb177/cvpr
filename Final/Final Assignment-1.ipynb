# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.datasets import mnist
import numpy as np
import matplotlib.pyplot as plt
import random
import os
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %%
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %%
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
print(f"Training images shape: {train_images.shape}, Training labels shape: {train_labels.shape}")
print(f"Test images shape: {test_images.shape}, Test labels shape: {test_labels.shape}")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Training images shape: (60000, 28, 28), Training labels shape: (60000,)
# Test images shape: (10000, 28, 28), Test labels shape: (10000,)

# %%
train_images = train_images.astype('float32') / 255.0
test_images = test_images.astype('float32') / 255.0

# %%
train_images = train_images.reshape(-1, 28, 28, 1)
test_images = test_images.reshape(-1, 28, 28, 1)

# %%
cnn_model = keras.Sequential([
    keras.Input(shape=(28, 28, 1)),
    layers.Conv2D(32, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')
])
cnn_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 11, 11, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1600)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       204,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 225,034 (879.04 KB)
#  Trainable params: 225,034 (879.04 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
cnn_model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
training_history = cnn_model.fit(
    train_images, train_labels,
    epochs=5,
    batch_size=64,
    validation_split=0.2
)
# Out:
# Epoch 1/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 43s 55ms/step - accuracy: 0.8723 - loss: 0.4229 - val_accuracy: 0.9792 - val_loss: 0.0696
# Epoch 2/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 82s 55ms/step - accuracy: 0.9838 - loss: 0.0530 - val_accuracy: 0.9849 - val_loss: 0.0499
# Epoch 3/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 81s 54ms/step - accuracy: 0.9883 - loss: 0.0362 - val_accuracy: 0.9875 - val_loss: 0.0424
# Epoch 4/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 41s 54ms/step - accuracy: 0.9923 - loss: 0.0254 - val_accuracy: 0.9883 - val_loss: 0.0375
# Epoch 5/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 41s 54ms/step - accuracy: 0.9934 - loss: 0.0203 - val_accuracy: 0.9886 - val_loss: 0.0361

# %%
eval_loss, eval_acc = cnn_model.evaluate(test_images, test_labels)
print(f"Test Accuracy: {eval_acc:.4f}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9864 - loss: 0.0378
# Test Accuracy: 0.9902

# %%
num_rows, num_cols = 3, 10
plt.figure(figsize=(20, 6))
for idx in range(num_rows * num_cols):
    sample_idx = random.randint(0, test_images.shape[0] - 1)
    sample_img = test_images[sample_idx].reshape(28, 28)
    predicted_label = np.argmax(cnn_model.predict(test_images[sample_idx:sample_idx + 1], verbose=0))
    plt.subplot(num_rows, num_cols, idx + 1)
    plt.imshow(sample_img, cmap='gray_r')
    plt.title(f"Pred: {predicted_label}\nTrue: {test_labels[sample_idx]}")
    plt.axis('off')
plt.tight_layout()
plt.show()

# %%
from tensorflow.keras.callbacks import ModelCheckpoint


checkpoint_callback = ModelCheckpoint(
    filepath='best_mnist_cnn_model.keras',
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=1
)


training_history = cnn_model.fit(
    train_images, train_labels,
    epochs=5,
    batch_size=64,
    validation_split=0.2,
    callbacks=[checkpoint_callback]
)
# Out:
# Epoch 1/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9952 - loss: 0.0139
# Epoch 1: val_accuracy improved from -inf to 0.98675, saving model to best_mnist_cnn_model.keras
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 41s 55ms/step - accuracy: 0.9952 - loss: 0.0139 - val_accuracy: 0.9868 - val_loss: 0.0497
# Epoch 2/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9964 - loss: 0.0110
# Epoch 2: val_accuracy improved from 0.98675 to 0.98933, saving model to best_mnist_cnn_model.keras
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 41s 54ms/step - accuracy: 0.9964 - loss: 0.0110 - val_accuracy: 0.9893 - val_loss: 0.0378
# Epoch 3/5
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9980 - loss: 0.0071
# Epoch 3: val_accuracy improved from 0.98933 to 0.98958, saving model to best_mnist_cnn_model.keras
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 41s 54ms/step - accuracy: 0.9980 - loss: 0.0072 - val_accuracy: 0.9896 - val_loss: 0.0424
# Epoch 4/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9974 - loss: 0.0080
# Epoch 4: val_accuracy did not improve from 0.98958
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 41s 54ms/step - accuracy: 0.9974 - loss: 0.0080 - val_accuracy: 0.9888 - val_loss: 0.0430
# Epoch 5/5
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9981 - loss: 0.0054
# Epoch 5: val_accuracy did not improve from 0.98958
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 41s 55ms/step - accuracy: 0.9981 - loss: 0.0054 - val_accuracy: 0.9871 - val_loss: 0.0535
